# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

# %%
df = pd.read_csv('data.csv')
df['correct'] = (df.true == df.pred)
df['(true=1,pred=1)'] = (df.true == 1) &  (df.pred == 1)
df['(true=1,pred=0)'] = (df.true == 1) &  (df.pred == 0)
df['(true=0,pred=1)'] = (df.true == 0) &  (df.pred == 1)
df['(true=0,pred=0)'] = (df.true == 0) &  (df.pred == 0)
df[:6]
# Out:
#    id  expt_id  duration  true  pred  age gender          filename  correct  \
# 0   1        1      5000     1     1   20   male  real/real-45.jpg     True
# 1   2        1      5000     0     0   20   male     gan/gan-7.jpg     True
# 2   3        1      5000     1     0   20   male  real/real-25.jpg    False
# 3   4        1      5000     0     0   20   male    gan/gan-31.jpg     True
# 4   5        1      5000     0     0   20   male    gan/gan-11.jpg     True
# 5   6        1      5000     1     1   20   male   real/real-5.jpg     True
#
#    (true=1,pred=1)  (true=1,pred=0)  (true=0,pred=1)  (true=0,pred=0)
# 0             True            False            False            False
# 1            False            False            False             True
# 2            False             True            False            False
# 3            False            False            False             True
# 4            False            False            False             True
# 5             True            False            False            False

# %%
dur1 = 1000
dur2 = 1000
id1 = 1
id2 = 2
exp1_data = df[(df.expt_id==id1) & (df.duration==dur1)].correct
exp2_data = df[(df.expt_id==id2) & (df.duration==dur2)].correct

print (exp1_data.mean())
print (exp2_data.mean())


from scipy.stats import ttest_ind

print (ttest_ind(exp1_data, exp2_data))
# Out:
# 0.5974842767295597
# 0.5614035087719298
# Ttest_indResult(statistic=0.9490635956566337, pvalue=0.3428542647931161)

# %%
indiv_df = df.groupby(by=lambda x: x//6, axis=0).agg({
    'expt_id': 'max',
    'duration': 'max',
    'age': 'max',
    'gender': 'max',
    'id': 'nunique',
    'true': 'sum',
    'correct': 'mean',
    '(true=1,pred=1)': 'sum',
    '(true=1,pred=0)': 'sum',
    '(true=0,pred=1)': 'sum',
    '(true=0,pred=0)': 'sum',
})


indiv_df['accuracy'] = indiv_df.correct
indiv_df['(pred=1|true=1)'] = indiv_df['(true=1,pred=1)'] / 3.
indiv_df['(pred=0|true=1)'] = indiv_df['(true=1,pred=0)'] / 3.
indiv_df['(pred=1|true=0)'] = indiv_df['(true=0,pred=1)'] / 3.
indiv_df['(pred=0|true=0)'] = indiv_df['(true=0,pred=0)'] / 3.

indiv_df = indiv_df[[
    'expt_id',
    'duration',
    'age',
    'gender',
    'id',
    'true',
    'accuracy',
    '(pred=1|true=1)',
    '(pred=0|true=1)',
    '(pred=1|true=0)',
    '(pred=0|true=0)',
]]

indiv_df.head()
# Out:
#    expt_id  duration  age gender  id  true  accuracy  (pred=1|true=1)  \
# 0        1      5000   20   male   6     3  0.833333         0.666667
# 1        1      2000   20   male   6     3  0.833333         1.000000
# 2        1      1000   20   male   6     3  0.500000         1.000000
# 3        1       500   20   male   6     3  0.500000         0.666667
# 4        1       250   20   male   6     3  0.333333         0.666667
#
#    (pred=0|true=1)  (pred=1|true=0)  (pred=0|true=0)
# 0         0.333333         0.000000         1.000000
# 1         0.000000         0.333333         0.666667
# 2         0.000000         1.000000         0.000000
# 3         0.333333         0.666667         0.333333
# 4         0.333333         1.000000         0.000000

# %%
def conf_interval(N, p_success):
    return (1.65/N)*np.sqrt(p_success*(1-p_success)*N) #90% conf interval


def get_results(df, columns):
    results = df.groupby(columns).agg({
        'id': 'sum',
        'true': 'sum',
        'accuracy': 'mean',
        '(pred=1|true=1)': 'mean',
        '(pred=0|true=1)':'mean',
        '(pred=1|true=0)': 'mean',
        '(pred=0|true=0)': 'mean',
    }).reset_index()
    
    results['accuracy_conf'] = conf_interval(results.id, results.accuracy)
    results['(pred=1|true=1)_conf'] = conf_interval(results.true, results['(pred=1|true=1)'])
    results['(pred=0|true=1)_conf'] = conf_interval(results.true, results['(pred=0|true=1)'])
    results['(pred=1|true=0)_conf'] = conf_interval(results.id-results.true, results['(pred=1|true=0)'])
    results['(pred=0|true=0)_conf'] = conf_interval(results.id-results.true, results['(pred=0|true=0)'])

    return results

indiv_results = get_results(indiv_df, ['expt_id', 'duration'])
indiv_gender_results = get_results(indiv_df, ['expt_id', 'duration', 'gender'])

indiv_results
# Out:
#    expt_id  duration   id  true  accuracy  (pred=1|true=1)  (pred=0|true=1)  \
# 0        1       250  570   287  0.547368         0.617544         0.389474
# 1        1       500  612   306  0.614379         0.614379         0.385621
# 2        1      1000  636   316  0.597484         0.528302         0.465409
# 3        1      2000  696   348  0.616379         0.574713         0.425287
# 4        1      5000  858   426  0.658508         0.589744         0.403263
# 5        2       250  222   120  0.495495         0.558559         0.522523
# 6        2       500  222   110  0.549550         0.459459         0.531532
# 7        2      1000  228   109  0.561404         0.500000         0.456140
# 8        2      2000  234   115  0.564103         0.478632         0.504274
# 9        2      5000  300   154  0.586667         0.586667         0.440000
#
#    (pred=1|true=0)  (pred=0|true=0)  accuracy_conf  (pred=1|true=1)_conf  \
# 0         0.515789         0.477193       0.034400              0.047333
# 1         0.385621         0.614379       0.032464              0.045912
# 2         0.339623         0.666667       0.032086              0.046335
# 3         0.341954         0.658046       0.030413              0.043728
# 4         0.279720         0.727273       0.026712              0.039322
# 5         0.486486         0.432432       0.055368              0.074794
# 6         0.369369         0.639640       0.055098              0.078402
# 7         0.421053         0.622807       0.054223              0.079021
# 8         0.367521         0.649573       0.053487              0.076861
# 9         0.386667         0.586667       0.046910              0.065474
#
#    (pred=0|true=1)_conf  (pred=1|true=0)_conf  (pred=0|true=0)_conf
# 0              0.047494              0.049017              0.048990
# 1              0.045912              0.045912              0.045912
# 2              0.046299              0.043682              0.043481
# 3              0.043728              0.041957              0.041957
# 4              0.039216              0.035633              0.035355
# 5              0.075235              0.081657              0.080938
# 6              0.078504              0.075248              0.074853
# 7              0.078716              0.074679              0.073311
# 8              0.076929              0.072925              0.072164
# 9              0.066000              0.066500              0.067244

# %%
recent = df[(df.id >= 1825) & (df.id <= 10000)]
user_df = recent[(recent.age == 21) & (recent.gender == 'female')]
user_df
# Out:
#         id  expt_id  duration  true  pred  age  gender          filename  \
# 1824  1825        1      5000     0     0   21  female    gan/gan-27.jpg
# 1825  1826        1      5000     0     0   21  female    gan/gan-21.jpg
# 1826  1827        1      5000     1     1   21  female  real/real-56.jpg
# 1827  1828        1      5000     1     1   21  female  real/real-47.jpg
# 1828  1829        1      5000     1     0   21  female  real/real-55.jpg
# 1829  1830        1      5000     0     0   21  female    gan/gan-33.jpg
# 1830  1831        1      2000     0     0   21  female    gan/gan-25.jpg
# 1831  1832        1      2000     0     0   21  female    gan/gan-37.jpg
# 1832  1833        1      2000     0     0   21  female     gan/gan-6.jpg
# 1833  1834        1      2000     1     0   21  female  real/real-51.jpg
# 1834  1835        1      2000     1     1   21  female  real/real-21.jpg
# 1835  1836        1      2000     1     1   21  female  real/real-48.jpg
# 1836  1837        1      1000     1     0   21  female   real/real-4.jpg
# 1837  1838        1      1000     1     0   21  female  real/real-26.jpg
# 1838  1839        1      1000     1     1   21  female  real/real-58.jpg
# 1839  1840        1      1000     0     1   21  female    gan/gan-15.jpg
# 1840  1841        1      1000     0     0   21  female    gan/gan-13.jpg
# 1841  1842        1      1000     0     1   21  female     gan/gan-1.jpg
# 1842  1843        1       500     1     1   21  female  real/real-21.jpg
# 1843  1844        1       500     0     1   21  female    gan/gan-34.jpg
# 1844  1845        1       500     0     1   21  female     gan/gan-1.jpg
# 1845  1846        1       500     1     0   21  female   real/real-1.jpg
# 1846  1847        1       500     0     0   21  female    gan/gan-11.jpg
# 1847  1848        1       500     1     0   21  female  real/real-29.jpg
# 1848  1849        1       250     0     0   21  female    gan/gan-40.jpg
# 1849  1850        1       250     0     0   21  female     gan/gan-7.jpg
# 1850  1851        1       250     0     1   21  female    gan/gan-42.jpg
# 1851  1852        1       250     1     0   21  female  real/real-56.jpg
# 1852  1853        1       250     1     1   21  female  real/real-28.jpg
# 1853  1854        1       250     1     1   21  female  real/real-37.jpg
# ...    ...      ...       ...   ...   ...  ...     ...               ...
# 3768  3769        1      5000     1     0   21  female  real/real-51.jpg
# 3769  3770        1      5000     0     1   21  female    gan/gan-12.jpg
# 3770  3771        1      5000     1     0   21  female  real/real-45.jpg
# 3771  3772        1      5000     0     1   21  female    gan/gan-31.jpg
# 3772  3773        1      5000     1     0   21  female  real/real-54.jpg
# 3773  3774        1      5000     0     0   21  female    gan/gan-35.jpg
# 3774  3775        1      2000     1     0   21  female  real/real-16.jpg
# 3775  3776        1      2000     1     1   21  female  real/real-28.jpg
# 3776  3777        1      2000     0     1   21  female     gan/gan-3.jpg
# 3777  3778        1      2000     1     0   21  female  real/real-47.jpg
# 3778  3779        1      2000     1     0   21  female   real/real-9.jpg
# 3779  3780        1      2000     1     0   21  female   real/real-7.jpg
# 3792  3793        1      1000     0     1   21  female     gan/gan-1.jpg
# 3793  3794        1      1000     1     1   21  female  real/real-14.jpg
# 3794  3795        1      1000     0     0   21  female     gan/gan-9.jpg
# 3795  3796        1      1000     0     0   21  female    gan/gan-34.jpg
# 3796  3797        1      1000     0     0   21  female    gan/gan-16.jpg
# 3797  3798        1      1000     1     0   21  female  real/real-26.jpg
# 3798  3799        1       500     0     1   21  female    gan/gan-17.jpg
# 3799  3800        1       500     0     0   21  female     gan/gan-4.jpg
# 3800  3801        1       500     1     0   21  female  real/real-32.jpg
# 3801  3802        1       500     1     0   21  female  real/real-56.jpg
# 3802  3803        1       500     1     1   21  female  real/real-33.jpg
# 3803  3804        1       500     0     0   21  female     gan/gan-5.jpg
# 3816  3817        1       250     0     1   21  female    gan/gan-27.jpg
# 3817  3818        1       250     0     1   21  female    gan/gan-11.jpg
# 3818  3819        1       250     1     1   21  female  real/real-48.jpg
# 3819  3820        1       250     0     0   21  female    gan/gan-26.jpg
# 3820  3821        1       250     0     0   21  female     gan/gan-2.jpg
# 3821  3822        1       250     1     0   21  female  real/real-36.jpg
#
#       correct  (true=1,pred=1)  (true=1,pred=0)  (true=0,pred=1)  \
# 1824     True            False            False            False
# 1825     True            False            False            False
# 1826     True             True            False            False
# 1827     True             True            False            False
# 1828    False            False             True            False
# 1829     True            False            False            False
# 1830     True            False            False            False
# 1831     True            False            False            False
# 1832     True            False            False            False
# 1833    False            False             True            False
# 1834     True             True            False            False
# 1835     True             True            False            False
# 1836    False            False             True            False
# 1837    False            False             True            False
# 1838     True             True            False            False
# 1839    False            False            False             True
# 1840     True            False            False            False
# 1841    False            False            False             True
# 1842     True             True            False            False
# 1843    False            False            False             True
# 1844    False            False            False             True
# 1845    False            False             True            False
# 1846     True            False            False            False
# 1847    False            False             True            False
# 1848     True            False            False            False
# 1849     True            False            False            False
# 1850    False            False            False             True
# 1851    False            False             True            False
# 1852     True             True            False            False
# 1853     True             True            False            False
# ...       ...              ...              ...              ...
# 3768    False            False             True            False
# 3769    False            False            False             True
# 3770    False            False             True            False
# 3771    False            False            False             True
# 3772    False            False             True            False
# 3773     True            False            False            False
# 3774    False            False             True            False
# 3775     True             True            False            False
# 3776    False            False            False             True
# 3777    False            False             True            False
# 3778    False            False             True            False
# 3779    False            False             True            False
# 3792    False            False            False             True
# 3793     True             True            False            False
# 3794     True            False            False            False
# 3795     True            False            False            False
# 3796     True            False            False            False
# 3797    False            False             True            False
# 3798    False            False            False             True
# 3799     True            False            False            False
# 3800    False            False             True            False
# 3801    False            False             True            False
# 3802     True             True            False            False
# 3803     True            False            False            False
# 3816    False            False            False             True
# 3817    False            False            False             True
# 3818     True             True            False            False
# 3819     True            False            False            False
# 3820     True            False            False            False
# 3821    False            False             True            False
#
#       (true=0,pred=0)
# 1824             True
# 1825             True
# 1826            False
# 1827            False
# 1828            False
# 1829             True
# 1830             True
# 1831             True
# 1832             True
# 1833            False
# 1834            False
# 1835            False
# 1836            False
# 1837            False
# 1838            False
# 1839            False
# 1840             True
# 1841            False
# 1842            False
# 1843            False
# 1844            False
# 1845            False
# 1846             True
# 1847            False
# 1848             True
# 1849             True
# 1850            False
# 1851            False
# 1852            False
# 1853            False
# ...               ...
# 3768            False
# 3769            False
# 3770            False
# 3771            False
# 3772            False
# 3773             True
# 3774            False
# 3775            False
# 3776            False
# 3777            False
# 3778            False
# 3779            False
# 3792            False
# 3793            False
# 3794             True
# 3795             True
# 3796             True
# 3797            False
# 3798            False
# 3799             True
# 3800            False
# 3801            False
# 3802            False
# 3803             True
# 3816            False
# 3817            False
# 3818            False
# 3819             True
# 3820             True
# 3821            False
#
# [330 rows x 13 columns]

# %%
print (user_df.groupby(['expt_id','duration']).id.count())
print (user_df.groupby(['expt_id','duration']).correct.sum())
# Out:
# expt_id  duration
# 1        250         36
#          500         42
#          1000        42
#          2000        42
#          5000        54
# 2        250         18
#          500         18
#          1000        24
#          2000        24
#          5000        30
# Name: id, dtype: int64
# expt_id  duration
# 1        250         19.0
#          500         25.0
#          1000        26.0
#          2000        27.0
#          5000        33.0
# 2        250          8.0
#          500         10.0
#          1000        13.0
#          2000         9.0
#          5000        19.0
# Name: correct, dtype: float64

# %% [markdown]
# 1) Overall, what is the distribution of real vs. fake responses per duration
# 2) What are the component of the error (FPR, FNR)
# 3) When eyes are removed, do people think images are fake more often

# %%
fig = plt.figure(figsize=(10,12))
ax1 = fig.add_subplot(211)
ax1.set_title("Face Classification Overall Accuracy vs. Time Shown")
ax1.set_xlabel("Time Shown (ms)")
ax1.set_ylabel("Accuracy = P(true == pred)")
ax2 = fig.add_subplot(212)
ax2.set_title("Fake Image FPR vs. Time Shown")
ax2.set_xlabel("Time Shown (ms)")
ax2.set_ylabel("FPR = P(pred=1|true=0)")

id_map = {
    1:("Exp 1 (real vs GAN)", "m", "-"), 
    2:("Exp 2 (real vs GAN; no eyes)", "m", "--")
}

for expt_id, (label, color, linestyle)  in id_map.items():
    exp_data = indiv_results[indiv_results.expt_id == expt_id]
    ax1.errorbar(exp_data.duration, exp_data['accuracy'], yerr=exp_data['accuracy_conf'],
                 color=color, linestyle=linestyle, marker='o', label=label, capsize=4)
    ax2.errorbar(exp_data.duration, exp_data['(pred=1|true=0)'], yerr=exp_data['(pred=1|true=0)_conf'],
                 color=color, linestyle=linestyle, marker='o', label=label, capsize=4)

#     exp_data = results[results.expt_id == expt_id]
#     ax1.plot(exp_data.duration, exp_data.accuracy, color=color, linestyle=linestyle, marker='o', label=label)
#     ax2.plot(exp_data.duration, exp_data['(pred=1|true=0)'], color=color, linestyle=linestyle, marker='o', label=label)
    
#     print (exp_data.accuracy)

ax1.axhline(y=0.5, color="k", linestyle="--", label="Random Guessing = 0.5")
ax2.axhline(y=0.5, color="k", linestyle="--", label="Random Guessing = 0.5")

ax1.legend(loc=0)
ax2.legend(loc=0)

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(10,12))
ax1 = fig.add_subplot(211)
ax1.set_title("Face Classification Overall Accuracy vs. Time Shown")
ax1.set_xlabel("Time Shown (ms)")
ax1.set_ylabel("Accuracy = P(true == pred)")

ax2 = fig.add_subplot(212)
ax2.set_title("Fake Image FPR vs. Time Shown")
ax2.set_xlabel("Time Shown (ms)")
ax2.set_ylabel("FPR = P(pred=1|true=0)")

gender_id_map = {
    ('male', 1):("Male; Exp 1 (real vs GAN)", "b", "-"), 
#     ('male', 2):("Male; Exp 2 (real vs GAN; no eyes)", "b", "--"),
    ('female', 1):("Female; Exp 1 (real vs GAN)", "r", "-"), 
#     ('female', 2):("Female; Exp 2 (real vs GAN; no eyes)", "r", "--")
}

for (gender, expt_id), (label, color, linestyle)  in gender_id_map.items():
    exp_data = indiv_gender_results[(indiv_gender_results.gender == gender) & (indiv_gender_results.expt_id == expt_id)]
    ax1.errorbar(exp_data.duration, exp_data['accuracy'], yerr=exp_data['accuracy_conf'],
                 color=color, linestyle=linestyle, marker='o', label=label, capsize=4)
    ax2.errorbar(exp_data.duration, exp_data['(pred=1|true=0)'], yerr=exp_data['(pred=1|true=0)_conf'],
                 color=color, linestyle=linestyle, marker='o', label=label, capsize=4)


ax1.axhline(y=0.5, color="k", linestyle="--", label="Random Guessing = 0.5")
ax2.axhline(y=0.5, color="k", linestyle="--", label="Random Guessing = 0.5")

ax1.legend(loc=0)
ax2.legend(loc=0)

plt.tight_layout()
plt.show()

# %%
print ("Exp 1, # datapoints: %d" % df[df.expt_id==1].id.count())
print ("Exp 2, # datapoints: %d" % df[df.expt_id==2].id.count())
# Out:
# Exp 1, # datapoints: 3372
# Exp 2, # datapoints: 1206

# %%
print(indiv_df.groupby(["expt_id", "duration"]).id.count().reset_index())
print(indiv_df.groupby(["expt_id", "duration", "gender"]).id.count().reset_index())
# Out:
#    expt_id  duration   id
# 0        1       250   95
# 1        1       500  102
# 2        1      1000  106
# 3        1      2000  116
# 4        1      5000  143
# 5        2       250   37
# 6        2       500   37
# 7        2      1000   38
# 8        2      2000   39
# 9        2      5000   50
#     expt_id  duration  gender  id
# 0         1       250  female  40
# 1         1       250    male  55
# 2         1       500  female  44
# 3         1       500    male  57
# 4         1       500   other   1
# 5         1      1000  female  44
# 6         1      1000    male  61
# 7         1      1000   other   1
# 8         1      2000  female  46
# 9         1      2000    male  69
# 10        1      2000   other   1
# 11        1      5000  female  51
# 12        1      5000    male  91
# 13        1      5000   other   1
# 14        2       250  female  19
# 15        2       250    male  18
# 16        2       500  female  19
# 17        2       500    male  18
# 18        2      1000  female  20
# 19        2      1000    male  18
# 20        2      2000  female  20
# 21        2      2000    male  19
# 22        2      5000  female  26
# 23        2      5000    male  24

# %%
img_df = df.groupby('filename').agg({
    'id': 'count',
    'expt_id':'max',
    'correct': 'sum',
    'true': 'max'
}).reset_index()
img_df['accuracy'] = img_df.correct / img_df.id



gender_img_df = df.groupby(['filename', 'gender']).agg({
    'id': 'count',
    'expt_id':'max',
    'correct': 'sum',
    'true': 'max'
}).reset_index()
gender_img_df['accuracy'] = gender_img_df.correct / gender_img_df.id

# %%
N = 6
expt_id = 1
true = 1
ascending = False

data = img_df[(img_df.true == true) & (img_df.expt_id == expt_id)].sort_values(by=['accuracy', 'id'], ascending=ascending).reset_index()

fig = plt.figure(figsize=(24,6))
for i in range(N):
    ax = fig.add_subplot('%d%d%d' % (1,N,i+1))
    ax.set_title("%s\nattempts=%d, correct=%d" % (data.filename[i], data.id[i], int(data.correct[i])))
    filepath = os.path.join('./server/static', data.filename[i])
    ax.imshow(mpimg.imread(filepath))
    ax.set_yticklabels([])
    ax.set_xticklabels([])

fig.savefig('./plots/hard_fake_exp1.svg')
plt.show()

# %%
N = 6
true = 1
expt_id = 1
ascending = True
gender = 'female'

data = gender_img_df[(gender_img_df.true == true) & (gender_img_df.expt_id == expt_id) & (gender_img_df.gender == gender)].sort_values(by=['accuracy', 'id'], ascending=ascending).reset_index()

fig = plt.figure(figsize=(20,4))
for i in range(N):
    ax = fig.add_subplot('%d%d%d' % (1,N,i+1))
    ax.set_title("%s\nattempts=%d, correct=%d" % (data.filename[i], data.id[i], int(data.correct[i])))
    filepath = os.path.join('./server/static', data.filename[i])
    ax.imshow(mpimg.imread(filepath))

plt.show()
